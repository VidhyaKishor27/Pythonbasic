# %% [markdown]
# <a href="https://colab.research.google.com/github/VidhyaKishor27/Pythonbasic/blob/main/Dataframe_missing_data%2Creplace%2Cduplicate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#dataframe with missing data, to replace values, find duplicate
#isna() & notna() -> find missing data in dataframe
#dropna(axis=0)-> drops the missind data row if, axis =1 drops col
#fillna()->fills up the missing data
#replace(old value,new value)-> replaces values in all the places where old value is given
#dulicated() ->find duplicates
import pandas as pd
df=pd.read_excel('/content/drive/MyDrive/Python training/missing data.xlsx')
#print(df)
print(df.isna()) # gives bool value for all data
print(df.isna().any()) # give bool value on col having missing data
print(df.fillna("missing"))
df.dropna(axis=0) # removes missing data rows from the dataframe
#print(df.replace(12345,1234))
# Out:
#     Ticket No  Passengar Name    Age    Sex  Boarded from  Destination  \
# 0       False           False  False  False         False        False
# 1       False           False  False  False         False        False
# 2       False           False  False  False         False        False
# 3       False           False  False  False          True        False
# 4       False           False  False  False         False        False
# 5       False           False  False  False         False        False
# 6       False           False  False  False         False        False
# 7       False           False  False  False         False        False
# 8       False           False  False  False         False        False
# 9       False           False  False  False         False        False
# 10      False           False  False  False          True        False
# 11      False           False  False  False         False        False
# ...
