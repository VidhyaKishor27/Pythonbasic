# %% [markdown]
# <a href="https://colab.research.google.com/github/VidhyaKishor27/Pythonbasic/blob/main/matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#using matplotlib
import matplotlib.pyplot as plt
import numpy as np
x = np.array([10,20,30,40])
y = np.array ([11,22,33,44])
pie_label=["car1","car2","car3","car4"]
pie_explode=[0,0,0,0.1]
plt.plot(x,y,'o--g')
plt.bar(x,y,width=0.9)
plt.grid(axis='x')
plt.xlabel('cars')
plt.ylabel('speed')
plt.title('speed of car')
plt.show()
plt.pie(x,labels=pie_label,explode=pie_explode)
plt.legend(title="Cars")
plt.show()
