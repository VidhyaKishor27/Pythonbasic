# %% [markdown]
# <a href="https://colab.research.google.com/github/VidhyaKishor27/Pythonbasic/blob/main/Pandas_Dataframe_Selection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Dataframe-Selection process from file
import pandas as pd
df=pd.read_excel('/content/drive/MyDrive/Python training/Passenger data (1).xlsx')
print(df)
print(df.columns)
print(df.shape)
age=df['Age']
print(age)
#print(df.loc[0,['Passengar Name','Destination']])
#print((df['Sex']=="Female") & (df['Age']>=80) ) # returns only boolean result for all values
#if need exact filtered value use loc()
print(df.loc[(df.Sex=="Male")&(df.Age==80)])
# Out:
#     Ticket No Passengar Name  Age     Sex Boarded from Destination  \
# 0         100            PN1   69    Male          MAS        PDKT
# 1         101            PN2   65  Female          MAS        PDKT
# 2         102            PN3   68    Male         PDKT         MAS
# 3         103            PN4   70    Male         PDKT         MAS
# 4         104            PN5   70    Male          MAS        PDKT
# 5         105            PN6   47  Female         PDKT         MAS
# 6         106            PN7   53  Female         PDKT         MAS
# 7         107            PN8   44    Male          MAS        PDKT
# 8         108            PN9   34  Female         PDKT         MAS
# 9         109           PN10   38    Male         PDKT         MAS
# 10        110           PN11   51  Female          MAS        PDKT
# 11        111           PN12   35  Female         PDKT         MAS
# 12        112           PN13   40  Female         PDKT         MAS
# ...
